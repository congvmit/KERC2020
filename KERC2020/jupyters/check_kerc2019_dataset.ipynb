# %%
import sys
sys.path.append('..')

# %%
import os
import mipkit
import numpy as np
import mipkit

# %%
from main_kerc2019 import KERC2019
from helper import load_args

# %%
kerc2019 = KERC2019()

# %%
args = load_args(is_notebook=True, verbose=False)

# %%
config = mipkit.load_yaml_config('../configs/kerc2019.yaml')
# Out:
# /home/congvm/Workspace/Research/mipkit/mipkit/sys.py:21: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f)

# %%
args.__dict__.update(config.__dict__)

# %%
args.train_csv
# Out:
# '/home/congvm/Dataset/dataset/train_kerc2019.csv'

# %%
args, dataloader, model = kerc2019.experiment_setup(args)
# Out:
# Load pretrained network!

# %%
for batch in dataloader.train_dataloader():
    break

# %%
batch['image'].shape
# Out:
# torch.Size([32, 3, 224, 224])

# %%
batch['label']
# Out:
# tensor([2, 5, 0, 5, 0, 5, 2, 5, 4, 3, 0, 5, 0, 5, 0, 2, 0, 6, 3, 0, 6, 0, 6, 5,
#         5, 3, 5, 6, 5, 5, 0, 6])

# %%
batch['image'][0:5].numpy().transpose([0, 2, 3, 1]).shape
# Out:
# (5, 224, 224, 3)

# %%
dataloader.train_dataset.convert_dict
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
for batch in dataloader.train_dataloader():
    break
    
for lbl in batch['label'][0:5]:
    print(lbl)

mipkit.show_multi_images(batch['image'][0:5].numpy().transpose([0, 2, 3, 1]))
# Out:
# tensor(0)
# tensor(4)
# tensor(0)
# tensor(6)
# tensor(3)

# %%
batch['image']
# Out:
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.3529, 0.3333, 0.3176],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3686, 0.3608, 0.3412],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3765, 0.3725, 0.3647]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.1882, 0.1804, 0.1725],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2039, 0.2000, 0.1922],
#           [0.0000, 0.0000, 0.0000,  ..., 0.2039, 0.2078, 0.2039]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
# ...
