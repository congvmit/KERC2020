# %%
import sys
sys.path.append('..')

from main_images import experiment_setup
from helper import load_args
import torch

args = load_args(is_notebook=True, verbose=False)

args.train_csv = '/home/congvm/Dataset/dataset/train_faces.csv'
args.val_csv = '/home/congvm/Dataset/dataset/valid_faces.csv'
args.data_dir = '/home/congvm/Dataset/'

args, dataloader, model = experiment_setup(args)

dataloader

model(torch.ones([3, 3, 224, 224]))

# %%
for tdata in dataloader.train_dataloader():
    break

# %%
mipkit.show_multi_images(tdata['image'].numpy().transpose((0, 2, 3, 1)))

# %%
for tdata in dataloader.val_dataloader():
    break

# %%
tdata
# Out:
# {'image': tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0039, 0.0078, 0.0118],
#            [0.0039, 0.0039, 0.0000,  ..., 0.0039, 0.0078, 0.0118],
#            [0.0039, 0.0039, 0.0039,  ..., 0.0039, 0.0078, 0.0118],
#            ...,
#            [0.0039, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0078, 0.0039, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0118, 0.0039, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.0039, 0.0078, 0.0118],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0039, 0.0078, 0.0118],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0039, 0.0078, 0.0118],
#            ...,
#            [0.0392, 0.0392, 0.0392,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0431, 0.0392, 0.0392,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0471, 0.0431, 0.0431,  ..., 0.0000, 0.0000, 0.0000]],
#
#           [[0.0157, 0.0157, 0.0157,  ..., 0.0078, 0.0078, 0.0118],
# ...

# %%
import mipkit

# %%
mipkit.show_multi_images(tdata['image'].numpy().transpose((0, 2, 3, 1)))
